# %%
import suftware as sw
import matplotlib.pyplot as plt
# %matplotlib inline
plt.ion()

# %%
dataset = sw.ExampleDataset('who.alcohol_consumption')
density = sw.DensityEstimator(dataset.data, num_grid_points=300)
density.plot()

# %%
import numpy as np
x = np.random.randn(30)
x

# %%
density = sw.DensityEstimator(x)
density.plot()
